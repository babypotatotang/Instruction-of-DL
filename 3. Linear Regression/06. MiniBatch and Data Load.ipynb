# %% [markdown]
# # **<u>06.미니 배치와 데이터 로드(Mini Batch and Data Load)</u>**
# * 선형회귀에 한정되지 않는 내용임.
# * **데이터를 로드하는 방법**과 `미니배치경사하강법`에 대해서 학습

# %% [markdown]
# ## **1. 미니 배치와 배치 크기(Mini Batch and Batch Size)**

# %%
x_train=torch.FloatTensor([[73,80,75],
                           [93,88,93],
                           [89,91,90],
                           [96,98,100],
                           [73,66,70]])
y_train=torch.FloatTensor([[152],[185],[180],[196],[142]])

# %% [markdown]
# * 샘플의 개수는 5개
# * 전체 데이터를 하나의 행렬로 선언하여 전체 데이터에 대해서 경사하강법을 수행
# * 데이터가 수십만개 이상이라면 전체 데이터에 대해서 경사 하강법을 수행하는 것은 매우 느리며, 많은 계산량 필요
# * 전체 데이터를 **더 작은 단위**로 나누어서 학습하는 `미니 배치(Mini Batch)` 개념 등장
#   1. 전체 데이터를 미니배치 단위로 나눔.
#   2. 미니배치만큼의 데이터를 로드, 해당 데이터에 대한 비용(`cost`)를 계산하고, `경사하강법`을 수행함.
#     * 미니배치의 개수만큼 경사하강법을 수행해야 전체 데이터가 한 번 전부 사용 (`1 epoch`)
#     * 미니배치의 개수는 미니배치의 크기에 따라 달라지며, 미니배치의 크기를 `batch size`라고 함.
#       - `batch size`는 **2의 제곱수**를 사용
#       - CPU와 GPU의 메모리가 2의 배수이므로 데이터 송수신의 효율을 높이기 위함.
#   3. 미니배치의 개수만큼 2를 반복
#   4. 전체 데이터에 대한 학습이 1회 끝나면 1 `에포크(epoch)`가 끝남.
#     * `epoch`: 전체 훈련 데이터가 학습에 한번 사용된 주기를 말함.
# * 경사하강법 분류
#   * **배치 경사 하강법**
#     - 전체 데이터에 대해서 한번에 경사 하강법을 수행하는 방법
#     - 전체 데이터를 사용하므로 가중치 값이 최적값에 수렴하는 과정이 안정적이지만, 계산량이 많음.
#   * **미니배치 경사 하강법**
#     - 미니 배치 단위로 경사하강법을 수행하는 방법
#     - 전체 데이터의 일부만을 보고 수행하므로 최적값으로 수렴하는 과정에서 헤맬 수 있지만, 훈련속도가 빠름.

# %% [markdown]
# ## **2. 이터레이션(Iteration)**
# * 한 번의 `epoch` 내에서 이루어지는 매개변수인 가중치 `w`와 편향 `b`의 업데이트 횟수
# * (예)
#   - Total Data = 2000
#   - Batch Size = 200
#   - Iteration = (Total Data) / (Batch Size) = 10

# %% [markdown]
# ## **3. 데이터 로드하기(Data Load)**
# * pytorch에서는 데이터를 쉽게 다룰 수 있도록 데이터셋(DataSet)과 데이터로더(DataLoader)를 제공.
#   * 다음의 기능을 제공
#     - 미니 배치 학습
#     - 데이터 셔플
#     - 병렬처리

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

#텐서 데이터셋
from torch.utils.data import TensorDataset
# 데이터 로더
from torch.utils.data import DataLoader

# %%
x_train=torch.FloatTensor([[73,80,75],
                           [93,88,93],
                           [89,91,90],
                           [96,98,100],
                           [73,66,70]])
y_train=torch.FloatTensor([[152],[185],[180],[196],[142]])

# %%
dataset=TensorDataset(x_train,y_train)
dataloader=DataLoader(dataset,batch_size=2,shuffle=True)

# %% [markdown]
# * DataLoader은 기본적으로 2개의 인자를 입력받음.
#   * 데이터셋
#   * 미니배치의 크기: 2의 배수
#   * shuffle: `epoch`마다 데이터셋을 섞어서 데이터가 학습되는 순서를 바꿈.

# %%
model=nn.Linear(3,1)
optimizer=torch.optim.SGD(model.parameters(),lr=1e-5)

# %%
nb_epochs=100
for epoch in range(nb_epochs+1):
    for batch_idx, samples in enumerate(dataloader):
        print(batch_idx)
        print(samples)
        x_train,y_train=samples

        #예측값, 비용
        prediction=model(x_train)
        cost=F.mse_loss(prediction,y_train)

        optimizer.zero_grad()
        cost.backward()
        optimizer.step()

        print('Epoch {:4d}/{} Batch {}/{} Cost: {:.6f}'.format(epoch,nb_epochs,batch_idx+1,len(dataloader),cost.item()))
# Out:
# 0
# [tensor([[89., 91., 90.],
#         [73., 80., 75.]]), tensor([[180.],
#         [152.]])]
# Epoch    0/100 Batch 1/3 Cost: 0.020022
# 1
# [tensor([[73., 66., 70.],
#         [93., 88., 93.]]), tensor([[142.],
#         [185.]])]
# Epoch    0/100 Batch 2/3 Cost: 4.758947
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch    0/100 Batch 3/3 Cost: 3.040430
# 0
# [tensor([[ 89.,  91.,  90.],
#         [ 96.,  98., 100.]]), tensor([[180.],
#         [196.]])]
# Epoch    1/100 Batch 1/3 Cost: 0.275865
# 1
# [tensor([[73., 66., 70.],
#         [73., 80., 75.]]), tensor([[142.],
#         [152.]])]
# Epoch    1/100 Batch 2/3 Cost: 3.730054
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch    1/100 Batch 3/3 Cost: 1.953366
# 0
# [tensor([[93., 88., 93.],
#         [73., 66., 70.]]), tensor([[185.],
#         [142.]])]
# Epoch    2/100 Batch 1/3 Cost: 1.724007
# 1
# [tensor([[73., 80., 75.],
#         [89., 91., 90.]]), tensor([[152.],
#         [180.]])]
# Epoch    2/100 Batch 2/3 Cost: 1.970386
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch    2/100 Batch 3/3 Cost: 3.048630
# 0
# [tensor([[ 93.,  88.,  93.],
#         [ 96.,  98., 100.]]), tensor([[185.],
#         [196.]])]
# Epoch    3/100 Batch 1/3 Cost: 1.838758
# 1
# [tensor([[73., 66., 70.],
#         [73., 80., 75.]]), tensor([[142.],
#         [152.]])]
# Epoch    3/100 Batch 2/3 Cost: 2.764035
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch    3/100 Batch 3/3 Cost: 0.574164
# 0
# [tensor([[93., 88., 93.],
#         [73., 66., 70.]]), tensor([[185.],
#         [142.]])]
# Epoch    4/100 Batch 1/3 Cost: 3.693516
# 1
# [tensor([[73., 80., 75.],
#         [89., 91., 90.]]), tensor([[152.],
#         [180.]])]
# Epoch    4/100 Batch 2/3 Cost: 0.974027
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch    4/100 Batch 3/3 Cost: 2.128413
# 0
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Epoch    5/100 Batch 1/3 Cost: 3.626767
# 1
# [tensor([[73., 80., 75.],
#         [89., 91., 90.]]), tensor([[152.],
#         [180.]])]
# Epoch    5/100 Batch 2/3 Cost: 0.044135
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch    5/100 Batch 3/3 Cost: 2.619986
# 0
# [tensor([[ 73.,  66.,  70.],
#         [ 96.,  98., 100.]]), tensor([[142.],
#         [196.]])]
# Epoch    6/100 Batch 1/3 Cost: 3.186906
# 1
# [tensor([[73., 80., 75.],
#         [93., 88., 93.]]), tensor([[152.],
#         [185.]])]
# Epoch    6/100 Batch 2/3 Cost: 0.566630
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch    6/100 Batch 3/3 Cost: 1.045208
# 0
# [tensor([[73., 80., 75.],
#         [93., 88., 93.]]), tensor([[152.],
#         [185.]])]
# Epoch    7/100 Batch 1/3 Cost: 0.878965
# 1
# [tensor([[89., 91., 90.],
#         [73., 66., 70.]]), tensor([[180.],
#         [142.]])]
# Epoch    7/100 Batch 2/3 Cost: 2.261386
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch    7/100 Batch 3/3 Cost: 2.970174
# 0
# [tensor([[73., 66., 70.],
#         [89., 91., 90.]]), tensor([[142.],
#         [180.]])]
# Epoch    8/100 Batch 1/3 Cost: 3.222535
# 1
# [tensor([[73., 80., 75.],
#         [93., 88., 93.]]), tensor([[152.],
#         [185.]])]
# Epoch    8/100 Batch 2/3 Cost: 0.870641
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch    8/100 Batch 3/3 Cost: 2.365474
# 0
# [tensor([[ 73.,  80.,  75.],
#         [ 96.,  98., 100.]]), tensor([[152.],
#         [196.]])]
# Epoch    9/100 Batch 1/3 Cost: 0.244766
# 1
# [tensor([[89., 91., 90.],
#         [93., 88., 93.]]), tensor([[180.],
#         [185.]])]
# Epoch    9/100 Batch 2/3 Cost: 1.941204
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch    9/100 Batch 3/3 Cost: 5.227938
# 0
# [tensor([[ 96.,  98., 100.],
#         [ 89.,  91.,  90.]]), tensor([[196.],
#         [180.]])]
# Epoch   10/100 Batch 1/3 Cost: 2.819678
# 1
# [tensor([[73., 66., 70.],
#         [73., 80., 75.]]), tensor([[142.],
#         [152.]])]
# Epoch   10/100 Batch 2/3 Cost: 2.576701
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   10/100 Batch 3/3 Cost: 1.014671
# 0
# [tensor([[73., 80., 75.],
#         [89., 91., 90.]]), tensor([[152.],
#         [180.]])]
# Epoch   11/100 Batch 1/3 Cost: 1.236250
# 1
# [tensor([[73., 66., 70.],
#         [93., 88., 93.]]), tensor([[142.],
#         [185.]])]
# Epoch   11/100 Batch 2/3 Cost: 2.409838
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch   11/100 Batch 3/3 Cost: 4.919466
# 0
# [tensor([[93., 88., 93.],
#         [89., 91., 90.]]), tensor([[185.],
#         [180.]])]
# Epoch   12/100 Batch 1/3 Cost: 1.271010
# 1
# [tensor([[73., 80., 75.],
#         [73., 66., 70.]]), tensor([[152.],
#         [142.]])]
# Epoch   12/100 Batch 2/3 Cost: 2.300473
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch   12/100 Batch 3/3 Cost: 2.807016
# 0
# [tensor([[73., 66., 70.],
#         [93., 88., 93.]]), tensor([[142.],
#         [185.]])]
# Epoch   13/100 Batch 1/3 Cost: 4.832099
# 1
# [tensor([[89., 91., 90.],
#         [73., 80., 75.]]), tensor([[180.],
#         [152.]])]
# Epoch   13/100 Batch 2/3 Cost: 0.628718
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch   13/100 Batch 3/3 Cost: 1.763349
# 0
# [tensor([[89., 91., 90.],
#         [73., 80., 75.]]), tensor([[180.],
#         [152.]])]
# Epoch   14/100 Batch 1/3 Cost: 0.057529
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 93.,  88.,  93.]]), tensor([[196.],
#         [185.]])]
# Epoch   14/100 Batch 2/3 Cost: 1.895671
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch   14/100 Batch 3/3 Cost: 5.590869
# 0
# [tensor([[89., 91., 90.],
#         [93., 88., 93.]]), tensor([[180.],
#         [185.]])]
# Epoch   15/100 Batch 1/3 Cost: 0.895274
# 1
# [tensor([[73., 66., 70.],
#         [73., 80., 75.]]), tensor([[142.],
#         [152.]])]
# Epoch   15/100 Batch 2/3 Cost: 1.763443
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch   15/100 Batch 3/3 Cost: 4.063605
# 0
# [tensor([[89., 91., 90.],
#         [93., 88., 93.]]), tensor([[180.],
#         [185.]])]
# Epoch   16/100 Batch 1/3 Cost: 1.374136
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  80.,  75.]]), tensor([[196.],
#         [152.]])]
# Epoch   16/100 Batch 2/3 Cost: 0.798170
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch   16/100 Batch 3/3 Cost: 5.976047
# 0
# [tensor([[73., 66., 70.],
#         [73., 80., 75.]]), tensor([[142.],
#         [152.]])]
# Epoch   17/100 Batch 1/3 Cost: 1.718136
# 1
# [tensor([[89., 91., 90.],
#         [93., 88., 93.]]), tensor([[180.],
#         [185.]])]
# Epoch   17/100 Batch 2/3 Cost: 0.964074
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch   17/100 Batch 3/3 Cost: 3.435464
# 0
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Epoch   18/100 Batch 1/3 Cost: 3.391215
# 1
# [tensor([[89., 91., 90.],
#         [73., 80., 75.]]), tensor([[180.],
#         [152.]])]
# Epoch   18/100 Batch 2/3 Cost: 0.074070
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   18/100 Batch 3/3 Cost: 2.406343
# 0
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  80.,  75.]]), tensor([[196.],
#         [152.]])]
# Epoch   19/100 Batch 1/3 Cost: 1.785645
# 1
# [tensor([[89., 91., 90.],
#         [73., 66., 70.]]), tensor([[180.],
#         [142.]])]
# Epoch   19/100 Batch 2/3 Cost: 2.591159
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   19/100 Batch 3/3 Cost: 1.132833
# 0
# [tensor([[ 73.,  80.,  75.],
#         [ 96.,  98., 100.]]), tensor([[152.],
#         [196.]])]
# Epoch   20/100 Batch 1/3 Cost: 2.426267
# 1
# [tensor([[93., 88., 93.],
#         [89., 91., 90.]]), tensor([[185.],
#         [180.]])]
# Epoch   20/100 Batch 2/3 Cost: 0.944390
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch   20/100 Batch 3/3 Cost: 4.001770
# 0
# [tensor([[89., 91., 90.],
#         [73., 66., 70.]]), tensor([[180.],
#         [142.]])]
# Epoch   21/100 Batch 1/3 Cost: 2.117208
# 1
# [tensor([[73., 80., 75.],
#         [93., 88., 93.]]), tensor([[152.],
#         [185.]])]
# Epoch   21/100 Batch 2/3 Cost: 0.501089
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch   21/100 Batch 3/3 Cost: 4.325265
# 0
# [tensor([[ 89.,  91.,  90.],
#         [ 96.,  98., 100.]]), tensor([[180.],
#         [196.]])]
# Epoch   22/100 Batch 1/3 Cost: 0.409893
# 1
# [tensor([[73., 66., 70.],
#         [93., 88., 93.]]), tensor([[142.],
#         [185.]])]
# Epoch   22/100 Batch 2/3 Cost: 5.265040
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch   22/100 Batch 3/3 Cost: 0.233630
# 0
# [tensor([[93., 88., 93.],
#         [73., 80., 75.]]), tensor([[185.],
#         [152.]])]
# Epoch   23/100 Batch 1/3 Cost: 0.682729
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 89.,  91.,  90.]]), tensor([[196.],
#         [180.]])]
# Epoch   23/100 Batch 2/3 Cost: 1.746525
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch   23/100 Batch 3/3 Cost: 5.639973
# 0
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  80.,  75.]]), tensor([[196.],
#         [152.]])]
# Epoch   24/100 Batch 1/3 Cost: 2.045153
# 1
# [tensor([[93., 88., 93.],
#         [89., 91., 90.]]), tensor([[185.],
#         [180.]])]
# Epoch   24/100 Batch 2/3 Cost: 0.992943
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch   24/100 Batch 3/3 Cost: 4.093003
# 0
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Epoch   25/100 Batch 1/3 Cost: 3.549625
# 1
# [tensor([[93., 88., 93.],
#         [73., 80., 75.]]), tensor([[185.],
#         [152.]])]
# Epoch   25/100 Batch 2/3 Cost: 0.461224
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch   25/100 Batch 3/3 Cost: 1.346848
# 0
# [tensor([[93., 88., 93.],
#         [73., 66., 70.]]), tensor([[185.],
#         [142.]])]
# Epoch   26/100 Batch 1/3 Cost: 2.949656
# 1
# [tensor([[ 73.,  80.,  75.],
#         [ 96.,  98., 100.]]), tensor([[152.],
#         [196.]])]
# Epoch   26/100 Batch 2/3 Cost: 2.457688
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch   26/100 Batch 3/3 Cost: 0.334334
# 0
# [tensor([[73., 66., 70.],
#         [89., 91., 90.]]), tensor([[142.],
#         [180.]])]
# Epoch   27/100 Batch 1/3 Cost: 2.764904
# 1
# [tensor([[ 93.,  88.,  93.],
#         [ 96.,  98., 100.]]), tensor([[185.],
#         [196.]])]
# Epoch   27/100 Batch 2/3 Cost: 1.603614
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch   27/100 Batch 3/3 Cost: 0.048240
# 0
# [tensor([[73., 80., 75.],
#         [93., 88., 93.]]), tensor([[152.],
#         [185.]])]
# Epoch   28/100 Batch 1/3 Cost: 0.881552
# 1
# [tensor([[73., 66., 70.],
#         [89., 91., 90.]]), tensor([[142.],
#         [180.]])]
# Epoch   28/100 Batch 2/3 Cost: 2.214104
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch   28/100 Batch 3/3 Cost: 2.898608
# 0
# [tensor([[93., 88., 93.],
#         [73., 80., 75.]]), tensor([[185.],
#         [152.]])]
# Epoch   29/100 Batch 1/3 Cost: 1.564439
# 1
# [tensor([[ 73.,  66.,  70.],
#         [ 96.,  98., 100.]]), tensor([[142.],
#         [196.]])]
# Epoch   29/100 Batch 2/3 Cost: 3.064472
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch   29/100 Batch 3/3 Cost: 0.377444
# 0
# [tensor([[93., 88., 93.],
#         [89., 91., 90.]]), tensor([[185.],
#         [180.]])]
# Epoch   30/100 Batch 1/3 Cost: 1.170185
# 1
# [tensor([[ 73.,  80.,  75.],
#         [ 96.,  98., 100.]]), tensor([[152.],
#         [196.]])]
# Epoch   30/100 Batch 2/3 Cost: 0.894189
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch   30/100 Batch 3/3 Cost: 5.738238
# 0
# [tensor([[93., 88., 93.],
#         [89., 91., 90.]]), tensor([[185.],
#         [180.]])]
# Epoch   31/100 Batch 1/3 Cost: 0.854215
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Epoch   31/100 Batch 2/3 Cost: 3.112979
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch   31/100 Batch 3/3 Cost: 0.219198
# 0
# [tensor([[73., 80., 75.],
#         [73., 66., 70.]]), tensor([[152.],
#         [142.]])]
# Epoch   32/100 Batch 1/3 Cost: 2.093494
# 1
# [tensor([[ 93.,  88.,  93.],
#         [ 96.,  98., 100.]]), tensor([[185.],
#         [196.]])]
# Epoch   32/100 Batch 2/3 Cost: 1.843843
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch   32/100 Batch 3/3 Cost: 0.545645
# 0
# [tensor([[73., 66., 70.],
#         [89., 91., 90.]]), tensor([[142.],
#         [180.]])]
# Epoch   33/100 Batch 1/3 Cost: 2.627920
# 1
# [tensor([[93., 88., 93.],
#         [73., 80., 75.]]), tensor([[185.],
#         [152.]])]
# Epoch   33/100 Batch 2/3 Cost: 0.647014
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch   33/100 Batch 3/3 Cost: 2.720617
# 0
# [tensor([[73., 66., 70.],
#         [89., 91., 90.]]), tensor([[142.],
#         [180.]])]
# Epoch   34/100 Batch 1/3 Cost: 3.179383
# 1
# [tensor([[ 73.,  80.,  75.],
#         [ 96.,  98., 100.]]), tensor([[152.],
#         [196.]])]
# Epoch   34/100 Batch 2/3 Cost: 0.735952
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   34/100 Batch 3/3 Cost: 2.733973
# 0
# [tensor([[89., 91., 90.],
#         [73., 80., 75.]]), tensor([[180.],
#         [152.]])]
# Epoch   35/100 Batch 1/3 Cost: 0.619243
# 1
# [tensor([[ 73.,  66.,  70.],
#         [ 96.,  98., 100.]]), tensor([[142.],
#         [196.]])]
# Epoch   35/100 Batch 2/3 Cost: 3.027987
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   35/100 Batch 3/3 Cost: 1.300747
# 0
# [tensor([[73., 66., 70.],
#         [93., 88., 93.]]), tensor([[142.],
#         [185.]])]
# Epoch   36/100 Batch 1/3 Cost: 1.448313
# 1
# [tensor([[ 89.,  91.,  90.],
#         [ 96.,  98., 100.]]), tensor([[180.],
#         [196.]])]
# Epoch   36/100 Batch 2/3 Cost: 4.426919
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch   36/100 Batch 3/3 Cost: 0.054532
# 0
# [tensor([[73., 80., 75.],
#         [93., 88., 93.]]), tensor([[152.],
#         [185.]])]
# Epoch   37/100 Batch 1/3 Cost: 0.843841
# 1
# [tensor([[73., 66., 70.],
#         [89., 91., 90.]]), tensor([[142.],
#         [180.]])]
# Epoch   37/100 Batch 2/3 Cost: 2.182994
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch   37/100 Batch 3/3 Cost: 2.914216
# 0
# [tensor([[89., 91., 90.],
#         [73., 80., 75.]]), tensor([[180.],
#         [152.]])]
# Epoch   38/100 Batch 1/3 Cost: 0.027642
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 93.,  88.,  93.]]), tensor([[196.],
#         [185.]])]
# Epoch   38/100 Batch 2/3 Cost: 1.752059
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch   38/100 Batch 3/3 Cost: 5.301531
# 0
# [tensor([[73., 80., 75.],
#         [73., 66., 70.]]), tensor([[152.],
#         [142.]])]
# Epoch   39/100 Batch 1/3 Cost: 1.587058
# 1
# [tensor([[93., 88., 93.],
#         [89., 91., 90.]]), tensor([[185.],
#         [180.]])]
# Epoch   39/100 Batch 2/3 Cost: 0.999254
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch   39/100 Batch 3/3 Cost: 3.531264
# 0
# [tensor([[73., 80., 75.],
#         [73., 66., 70.]]), tensor([[152.],
#         [142.]])]
# Epoch   40/100 Batch 1/3 Cost: 3.000759
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 89.,  91.,  90.]]), tensor([[196.],
#         [180.]])]
# Epoch   40/100 Batch 2/3 Cost: 1.086469
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   40/100 Batch 3/3 Cost: 2.833050
# 0
# [tensor([[ 73.,  66.,  70.],
#         [ 96.,  98., 100.]]), tensor([[142.],
#         [196.]])]
# Epoch   41/100 Batch 1/3 Cost: 3.059579
# 1
# [tensor([[73., 80., 75.],
#         [89., 91., 90.]]), tensor([[152.],
#         [180.]])]
# Epoch   41/100 Batch 2/3 Cost: 0.447681
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   41/100 Batch 3/3 Cost: 1.550735
# 0
# [tensor([[89., 91., 90.],
#         [93., 88., 93.]]), tensor([[180.],
#         [185.]])]
# Epoch   42/100 Batch 1/3 Cost: 0.871262
# 1
# [tensor([[73., 80., 75.],
#         [73., 66., 70.]]), tensor([[152.],
#         [142.]])]
# Epoch   42/100 Batch 2/3 Cost: 1.689103
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch   42/100 Batch 3/3 Cost: 4.020657
# 0
# [tensor([[93., 88., 93.],
#         [89., 91., 90.]]), tensor([[185.],
#         [180.]])]
# Epoch   43/100 Batch 1/3 Cost: 1.328336
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Epoch   43/100 Batch 2/3 Cost: 3.024527
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch   43/100 Batch 3/3 Cost: 0.052003
# 0
# [tensor([[93., 88., 93.],
#         [73., 80., 75.]]), tensor([[185.],
#         [152.]])]
# Epoch   44/100 Batch 1/3 Cost: 0.829522
# 1
# [tensor([[ 89.,  91.,  90.],
#         [ 96.,  98., 100.]]), tensor([[180.],
#         [196.]])]
# Epoch   44/100 Batch 2/3 Cost: 1.480708
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch   44/100 Batch 3/3 Cost: 5.678232
# 0
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Epoch   45/100 Batch 1/3 Cost: 3.133975
# 1
# [tensor([[93., 88., 93.],
#         [89., 91., 90.]]), tensor([[185.],
#         [180.]])]
# Epoch   45/100 Batch 2/3 Cost: 0.798201
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch   45/100 Batch 3/3 Cost: 0.233895
# 0
# [tensor([[ 73.,  66.,  70.],
#         [ 96.,  98., 100.]]), tensor([[142.],
#         [196.]])]
# Epoch   46/100 Batch 1/3 Cost: 2.991673
# 1
# [tensor([[93., 88., 93.],
#         [89., 91., 90.]]), tensor([[185.],
#         [180.]])]
# Epoch   46/100 Batch 2/3 Cost: 0.833406
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch   46/100 Batch 3/3 Cost: 0.151743
# 0
# [tensor([[73., 66., 70.],
#         [93., 88., 93.]]), tensor([[142.],
#         [185.]])]
# Epoch   47/100 Batch 1/3 Cost: 2.732857
# 1
# [tensor([[89., 91., 90.],
#         [73., 80., 75.]]), tensor([[180.],
#         [152.]])]
# Epoch   47/100 Batch 2/3 Cost: 1.188498
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch   47/100 Batch 3/3 Cost: 2.401658
# 0
# [tensor([[93., 88., 93.],
#         [73., 80., 75.]]), tensor([[185.],
#         [152.]])]
# Epoch   48/100 Batch 1/3 Cost: 1.650475
# 1
# [tensor([[73., 66., 70.],
#         [89., 91., 90.]]), tensor([[142.],
#         [180.]])]
# Epoch   48/100 Batch 2/3 Cost: 2.424018
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch   48/100 Batch 3/3 Cost: 2.273821
# 0
# [tensor([[ 96.,  98., 100.],
#         [ 89.,  91.,  90.]]), tensor([[196.],
#         [180.]])]
# Epoch   49/100 Batch 1/3 Cost: 0.204083
# 1
# [tensor([[73., 66., 70.],
#         [73., 80., 75.]]), tensor([[142.],
#         [152.]])]
# Epoch   49/100 Batch 2/3 Cost: 3.665241
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   49/100 Batch 3/3 Cost: 1.891926
# 0
# [tensor([[ 96.,  98., 100.],
#         [ 93.,  88.,  93.]]), tensor([[196.],
#         [185.]])]
# Epoch   50/100 Batch 1/3 Cost: 1.933265
# 1
# [tensor([[73., 80., 75.],
#         [89., 91., 90.]]), tensor([[152.],
#         [180.]])]
# Epoch   50/100 Batch 2/3 Cost: 0.364759
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch   50/100 Batch 3/3 Cost: 4.558397
# 0
# [tensor([[93., 88., 93.],
#         [73., 80., 75.]]), tensor([[185.],
#         [152.]])]
# Epoch   51/100 Batch 1/3 Cost: 0.440081
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 89.,  91.,  90.]]), tensor([[196.],
#         [180.]])]
# Epoch   51/100 Batch 2/3 Cost: 2.843915
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch   51/100 Batch 3/3 Cost: 4.864927
# 0
# [tensor([[73., 66., 70.],
#         [89., 91., 90.]]), tensor([[142.],
#         [180.]])]
# Epoch   52/100 Batch 1/3 Cost: 1.997671
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 93.,  88.,  93.]]), tensor([[196.],
#         [185.]])]
# Epoch   52/100 Batch 2/3 Cost: 2.146092
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch   52/100 Batch 3/3 Cost: 0.172917
# 0
# [tensor([[73., 80., 75.],
#         [73., 66., 70.]]), tensor([[152.],
#         [142.]])]
# Epoch   53/100 Batch 1/3 Cost: 2.053580
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 93.,  88.,  93.]]), tensor([[196.],
#         [185.]])]
# Epoch   53/100 Batch 2/3 Cost: 1.809203
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch   53/100 Batch 3/3 Cost: 0.526896
# 0
# [tensor([[89., 91., 90.],
#         [93., 88., 93.]]), tensor([[180.],
#         [185.]])]
# Epoch   54/100 Batch 1/3 Cost: 1.065300
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Epoch   54/100 Batch 2/3 Cost: 2.972637
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch   54/100 Batch 3/3 Cost: 0.068273
# 0
# [tensor([[73., 80., 75.],
#         [73., 66., 70.]]), tensor([[152.],
#         [142.]])]
# Epoch   55/100 Batch 1/3 Cost: 2.213608
# 1
# [tensor([[ 89.,  91.,  90.],
#         [ 96.,  98., 100.]]), tensor([[180.],
#         [196.]])]
# Epoch   55/100 Batch 2/3 Cost: 1.768646
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   55/100 Batch 3/3 Cost: 2.341970
# 0
# [tensor([[ 89.,  91.,  90.],
#         [ 96.,  98., 100.]]), tensor([[180.],
#         [196.]])]
# Epoch   56/100 Batch 1/3 Cost: 2.043660
# 1
# [tensor([[73., 66., 70.],
#         [73., 80., 75.]]), tensor([[142.],
#         [152.]])]
# Epoch   56/100 Batch 2/3 Cost: 2.623307
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   56/100 Batch 3/3 Cost: 1.074299
# 0
# [tensor([[89., 91., 90.],
#         [73., 80., 75.]]), tensor([[180.],
#         [152.]])]
# Epoch   57/100 Batch 1/3 Cost: 1.069727
# 1
# [tensor([[ 73.,  66.,  70.],
#         [ 96.,  98., 100.]]), tensor([[142.],
#         [196.]])]
# Epoch   57/100 Batch 2/3 Cost: 2.969070
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   57/100 Batch 3/3 Cost: 1.051958
# 0
# [tensor([[73., 80., 75.],
#         [89., 91., 90.]]), tensor([[152.],
#         [180.]])]
# Epoch   58/100 Batch 1/3 Cost: 1.076782
# 1
# [tensor([[93., 88., 93.],
#         [73., 66., 70.]]), tensor([[185.],
#         [142.]])]
# Epoch   58/100 Batch 2/3 Cost: 2.294814
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch   58/100 Batch 3/3 Cost: 4.713462
# 0
# [tensor([[93., 88., 93.],
#         [73., 66., 70.]]), tensor([[185.],
#         [142.]])]
# Epoch   59/100 Batch 1/3 Cost: 3.892740
# 1
# [tensor([[ 73.,  80.,  75.],
#         [ 96.,  98., 100.]]), tensor([[152.],
#         [196.]])]
# Epoch   59/100 Batch 2/3 Cost: 1.814339
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch   59/100 Batch 3/3 Cost: 0.211255
# 0
# [tensor([[73., 66., 70.],
#         [73., 80., 75.]]), tensor([[142.],
#         [152.]])]
# Epoch   60/100 Batch 1/3 Cost: 2.728431
# 1
# [tensor([[ 93.,  88.,  93.],
#         [ 96.,  98., 100.]]), tensor([[185.],
#         [196.]])]
# Epoch   60/100 Batch 2/3 Cost: 1.575196
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch   60/100 Batch 3/3 Cost: 0.345149
# 0
# [tensor([[73., 66., 70.],
#         [73., 80., 75.]]), tensor([[142.],
#         [152.]])]
# Epoch   61/100 Batch 1/3 Cost: 2.604504
# 1
# [tensor([[93., 88., 93.],
#         [89., 91., 90.]]), tensor([[185.],
#         [180.]])]
# Epoch   61/100 Batch 2/3 Cost: 0.804463
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch   61/100 Batch 3/3 Cost: 2.373930
# 0
# [tensor([[73., 80., 75.],
#         [89., 91., 90.]]), tensor([[152.],
#         [180.]])]
# Epoch   62/100 Batch 1/3 Cost: 0.045580
# 1
# [tensor([[73., 66., 70.],
#         [93., 88., 93.]]), tensor([[142.],
#         [185.]])]
# Epoch   62/100 Batch 2/3 Cost: 4.520891
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch   62/100 Batch 3/3 Cost: 2.846626
# 0
# [tensor([[73., 80., 75.],
#         [73., 66., 70.]]), tensor([[152.],
#         [142.]])]
# Epoch   63/100 Batch 1/3 Cost: 3.082386
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 93.,  88.,  93.]]), tensor([[196.],
#         [185.]])]
# Epoch   63/100 Batch 2/3 Cost: 1.533712
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch   63/100 Batch 3/3 Cost: 0.280931
# 0
# [tensor([[ 73.,  66.,  70.],
#         [ 96.,  98., 100.]]), tensor([[142.],
#         [196.]])]
# Epoch   64/100 Batch 1/3 Cost: 3.099223
# 1
# [tensor([[73., 80., 75.],
#         [93., 88., 93.]]), tensor([[152.],
#         [185.]])]
# Epoch   64/100 Batch 2/3 Cost: 0.871886
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch   64/100 Batch 3/3 Cost: 0.580843
# 0
# [tensor([[ 93.,  88.,  93.],
#         [ 96.,  98., 100.]]), tensor([[185.],
#         [196.]])]
# Epoch   65/100 Batch 1/3 Cost: 1.536462
# 1
# [tensor([[89., 91., 90.],
#         [73., 80., 75.]]), tensor([[180.],
#         [152.]])]
# Epoch   65/100 Batch 2/3 Cost: 0.102221
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch   65/100 Batch 3/3 Cost: 5.110127
# 0
# [tensor([[73., 80., 75.],
#         [93., 88., 93.]]), tensor([[152.],
#         [185.]])]
# Epoch   66/100 Batch 1/3 Cost: 0.407191
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Epoch   66/100 Batch 2/3 Cost: 3.148962
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch   66/100 Batch 3/3 Cost: 0.931071
# 0
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Epoch   67/100 Batch 1/3 Cost: 2.968303
# 1
# [tensor([[89., 91., 90.],
#         [93., 88., 93.]]), tensor([[180.],
#         [185.]])]
# Epoch   67/100 Batch 2/3 Cost: 0.872410
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch   67/100 Batch 3/3 Cost: 0.097237
# 0
# [tensor([[73., 66., 70.],
#         [93., 88., 93.]]), tensor([[142.],
#         [185.]])]
# Epoch   68/100 Batch 1/3 Cost: 2.755719
# 1
# [tensor([[ 89.,  91.,  90.],
#         [ 96.,  98., 100.]]), tensor([[180.],
#         [196.]])]
# Epoch   68/100 Batch 2/3 Cost: 2.892807
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch   68/100 Batch 3/3 Cost: 0.002649
# 0
# [tensor([[ 96.,  98., 100.],
#         [ 93.,  88.,  93.]]), tensor([[196.],
#         [185.]])]
# Epoch   69/100 Batch 1/3 Cost: 1.528272
# 1
# [tensor([[89., 91., 90.],
#         [73., 80., 75.]]), tensor([[180.],
#         [152.]])]
# Epoch   69/100 Batch 2/3 Cost: 0.104012
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch   69/100 Batch 3/3 Cost: 5.075417
# 0
# [tensor([[73., 66., 70.],
#         [89., 91., 90.]]), tensor([[142.],
#         [180.]])]
# Epoch   70/100 Batch 1/3 Cost: 1.960959
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  80.,  75.]]), tensor([[196.],
#         [152.]])]
# Epoch   70/100 Batch 2/3 Cost: 2.138199
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   70/100 Batch 3/3 Cost: 1.521912
# 0
# [tensor([[73., 80., 75.],
#         [93., 88., 93.]]), tensor([[152.],
#         [185.]])]
# Epoch   71/100 Batch 1/3 Cost: 0.402530
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Epoch   71/100 Batch 2/3 Cost: 3.120842
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch   71/100 Batch 3/3 Cost: 0.906296
# 0
# [tensor([[73., 80., 75.],
#         [73., 66., 70.]]), tensor([[152.],
#         [142.]])]
# Epoch   72/100 Batch 1/3 Cost: 2.257442
# 1
# [tensor([[ 89.,  91.,  90.],
#         [ 96.,  98., 100.]]), tensor([[180.],
#         [196.]])]
# Epoch   72/100 Batch 2/3 Cost: 1.652979
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   72/100 Batch 3/3 Cost: 2.348466
# 0
# [tensor([[ 73.,  80.,  75.],
#         [ 96.,  98., 100.]]), tensor([[152.],
#         [196.]])]
# Epoch   73/100 Batch 1/3 Cost: 1.636269
# 1
# [tensor([[89., 91., 90.],
#         [93., 88., 93.]]), tensor([[180.],
#         [185.]])]
# Epoch   73/100 Batch 2/3 Cost: 0.986004
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch   73/100 Batch 3/3 Cost: 3.981223
# 0
# [tensor([[73., 66., 70.],
#         [93., 88., 93.]]), tensor([[142.],
#         [185.]])]
# Epoch   74/100 Batch 1/3 Cost: 1.058325
# 1
# [tensor([[ 89.,  91.,  90.],
#         [ 96.,  98., 100.]]), tensor([[180.],
#         [196.]])]
# Epoch   74/100 Batch 2/3 Cost: 4.815820
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch   74/100 Batch 3/3 Cost: 0.055441
# 0
# [tensor([[ 96.,  98., 100.],
#         [ 89.,  91.,  90.]]), tensor([[196.],
#         [180.]])]
# Epoch   75/100 Batch 1/3 Cost: 0.939137
# 1
# [tensor([[73., 66., 70.],
#         [73., 80., 75.]]), tensor([[142.],
#         [152.]])]
# Epoch   75/100 Batch 2/3 Cost: 2.982168
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   75/100 Batch 3/3 Cost: 1.357921
# 0
# [tensor([[93., 88., 93.],
#         [73., 80., 75.]]), tensor([[185.],
#         [152.]])]
# Epoch   76/100 Batch 1/3 Cost: 0.395019
# 1
# [tensor([[ 73.,  66.,  70.],
#         [ 96.,  98., 100.]]), tensor([[142.],
#         [196.]])]
# Epoch   76/100 Batch 2/3 Cost: 3.123702
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch   76/100 Batch 3/3 Cost: 0.920763
# 0
# [tensor([[93., 88., 93.],
#         [73., 66., 70.]]), tensor([[185.],
#         [142.]])]
# Epoch   77/100 Batch 1/3 Cost: 3.029993
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 89.,  91.,  90.]]), tensor([[196.],
#         [180.]])]
# Epoch   77/100 Batch 2/3 Cost: 2.649454
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch   77/100 Batch 3/3 Cost: 0.000239
# 0
# [tensor([[73., 66., 70.],
#         [93., 88., 93.]]), tensor([[142.],
#         [185.]])]
# Epoch   78/100 Batch 1/3 Cost: 3.354200
# 1
# [tensor([[73., 80., 75.],
#         [89., 91., 90.]]), tensor([[152.],
#         [180.]])]
# Epoch   78/100 Batch 2/3 Cost: 0.852264
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch   78/100 Batch 3/3 Cost: 2.092105
# 0
# [tensor([[89., 91., 90.],
#         [73., 66., 70.]]), tensor([[180.],
#         [142.]])]
# Epoch   79/100 Batch 1/3 Cost: 3.178629
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  80.,  75.]]), tensor([[196.],
#         [152.]])]
# Epoch   79/100 Batch 2/3 Cost: 0.650493
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   79/100 Batch 3/3 Cost: 2.651198
# 0
# [tensor([[93., 88., 93.],
#         [73., 80., 75.]]), tensor([[185.],
#         [152.]])]
# Epoch   80/100 Batch 1/3 Cost: 0.442042
# 1
# [tensor([[ 89.,  91.,  90.],
#         [ 96.,  98., 100.]]), tensor([[180.],
#         [196.]])]
# Epoch   80/100 Batch 2/3 Cost: 2.130105
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch   80/100 Batch 3/3 Cost: 5.048571
# 0
# [tensor([[73., 80., 75.],
#         [89., 91., 90.]]), tensor([[152.],
#         [180.]])]
# Epoch   81/100 Batch 1/3 Cost: 0.889198
# 1
# [tensor([[ 73.,  66.,  70.],
#         [ 96.,  98., 100.]]), tensor([[142.],
#         [196.]])]
# Epoch   81/100 Batch 2/3 Cost: 2.899678
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   81/100 Batch 3/3 Cost: 1.068392
# 0
# [tensor([[ 96.,  98., 100.],
#         [ 93.,  88.,  93.]]), tensor([[196.],
#         [185.]])]
# Epoch   82/100 Batch 1/3 Cost: 2.107744
# 1
# [tensor([[89., 91., 90.],
#         [73., 66., 70.]]), tensor([[180.],
#         [142.]])]
# Epoch   82/100 Batch 2/3 Cost: 2.047178
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch   82/100 Batch 3/3 Cost: 0.252217
# 0
# [tensor([[73., 80., 75.],
#         [93., 88., 93.]]), tensor([[152.],
#         [185.]])]
# Epoch   83/100 Batch 1/3 Cost: 0.533784
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Epoch   83/100 Batch 2/3 Cost: 2.952359
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch   83/100 Batch 3/3 Cost: 0.683165
# 0
# [tensor([[ 89.,  91.,  90.],
#         [ 96.,  98., 100.]]), tensor([[180.],
#         [196.]])]
# Epoch   84/100 Batch 1/3 Cost: 0.714055
# 1
# [tensor([[73., 66., 70.],
#         [93., 88., 93.]]), tensor([[142.],
#         [185.]])]
# Epoch   84/100 Batch 2/3 Cost: 4.532000
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch   84/100 Batch 3/3 Cost: 0.205184
# 0
# [tensor([[89., 91., 90.],
#         [93., 88., 93.]]), tensor([[180.],
#         [185.]])]
# Epoch   85/100 Batch 1/3 Cost: 0.780696
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Epoch   85/100 Batch 2/3 Cost: 2.900267
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch   85/100 Batch 3/3 Cost: 0.096430
# 0
# [tensor([[73., 80., 75.],
#         [73., 66., 70.]]), tensor([[152.],
#         [142.]])]
# Epoch   86/100 Batch 1/3 Cost: 2.023086
# 1
# [tensor([[ 93.,  88.,  93.],
#         [ 96.,  98., 100.]]), tensor([[185.],
#         [196.]])]
# Epoch   86/100 Batch 2/3 Cost: 1.743462
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch   86/100 Batch 3/3 Cost: 0.490124
# 0
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Epoch   87/100 Batch 1/3 Cost: 2.971876
# 1
# [tensor([[93., 88., 93.],
#         [73., 80., 75.]]), tensor([[185.],
#         [152.]])]
# Epoch   87/100 Batch 2/3 Cost: 0.783713
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch   87/100 Batch 3/3 Cost: 0.615871
# 0
# [tensor([[89., 91., 90.],
#         [73., 66., 70.]]), tensor([[180.],
#         [142.]])]
# Epoch   88/100 Batch 1/3 Cost: 2.429625
# 1
# [tensor([[ 73.,  80.,  75.],
#         [ 96.,  98., 100.]]), tensor([[152.],
#         [196.]])]
# Epoch   88/100 Batch 2/3 Cost: 1.062459
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   88/100 Batch 3/3 Cost: 2.162025
# 0
# [tensor([[89., 91., 90.],
#         [73., 80., 75.]]), tensor([[180.],
#         [152.]])]
# Epoch   89/100 Batch 1/3 Cost: 0.638522
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Epoch   89/100 Batch 2/3 Cost: 2.877361
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   89/100 Batch 3/3 Cost: 1.163933
# 0
# [tensor([[93., 88., 93.],
#         [89., 91., 90.]]), tensor([[185.],
#         [180.]])]
# Epoch   90/100 Batch 1/3 Cost: 0.857098
# 1
# [tensor([[73., 66., 70.],
#         [73., 80., 75.]]), tensor([[142.],
#         [152.]])]
# Epoch   90/100 Batch 2/3 Cost: 1.552713
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch   90/100 Batch 3/3 Cost: 4.011666
# 0
# [tensor([[73., 66., 70.],
#         [93., 88., 93.]]), tensor([[142.],
#         [185.]])]
# Epoch   91/100 Batch 1/3 Cost: 3.961468
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  80.,  75.]]), tensor([[196.],
#         [152.]])]
# Epoch   91/100 Batch 2/3 Cost: 1.664222
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch   91/100 Batch 3/3 Cost: 0.188666
# 0
# [tensor([[73., 66., 70.],
#         [73., 80., 75.]]), tensor([[142.],
#         [152.]])]
# Epoch   92/100 Batch 1/3 Cost: 2.656760
# 1
# [tensor([[89., 91., 90.],
#         [93., 88., 93.]]), tensor([[180.],
#         [185.]])]
# Epoch   92/100 Batch 2/3 Cost: 0.788145
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch   92/100 Batch 3/3 Cost: 2.253984
# 0
# [tensor([[93., 88., 93.],
#         [73., 66., 70.]]), tensor([[185.],
#         [142.]])]
# Epoch   93/100 Batch 1/3 Cost: 4.645782
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  80.,  75.]]), tensor([[196.],
#         [152.]])]
# Epoch   93/100 Batch 2/3 Cost: 1.398247
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch   93/100 Batch 3/3 Cost: 0.137416
# 0
# [tensor([[73., 66., 70.],
#         [93., 88., 93.]]), tensor([[142.],
#         [185.]])]
# Epoch   94/100 Batch 1/3 Cost: 3.904335
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  80.,  75.]]), tensor([[196.],
#         [152.]])]
# Epoch   94/100 Batch 2/3 Cost: 1.677175
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch   94/100 Batch 3/3 Cost: 0.191941
# 0
# [tensor([[89., 91., 90.],
#         [93., 88., 93.]]), tensor([[180.],
#         [185.]])]
# Epoch   95/100 Batch 1/3 Cost: 1.174166
# 1
# [tensor([[ 73.,  80.,  75.],
#         [ 96.,  98., 100.]]), tensor([[152.],
#         [196.]])]
# Epoch   95/100 Batch 2/3 Cost: 0.786471
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch   95/100 Batch 3/3 Cost: 5.402348
# 0
# [tensor([[ 93.,  88.,  93.],
#         [ 96.,  98., 100.]]), tensor([[185.],
#         [196.]])]
# Epoch   96/100 Batch 1/3 Cost: 1.860516
# 1
# [tensor([[73., 80., 75.],
#         [89., 91., 90.]]), tensor([[152.],
#         [180.]])]
# Epoch   96/100 Batch 2/3 Cost: 0.323637
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch   96/100 Batch 3/3 Cost: 4.317208
# 0
# [tensor([[73., 66., 70.],
#         [93., 88., 93.]]), tensor([[142.],
#         [185.]])]
# Epoch   97/100 Batch 1/3 Cost: 1.178644
# 1
# [tensor([[89., 91., 90.],
#         [73., 80., 75.]]), tensor([[180.],
#         [152.]])]
# Epoch   97/100 Batch 2/3 Cost: 1.974949
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch   97/100 Batch 3/3 Cost: 3.203420
# 0
# [tensor([[73., 80., 75.],
#         [93., 88., 93.]]), tensor([[152.],
#         [185.]])]
# Epoch   98/100 Batch 1/3 Cost: 1.382933
# 1
# [tensor([[73., 66., 70.],
#         [89., 91., 90.]]), tensor([[142.],
#         [180.]])]
# Epoch   98/100 Batch 2/3 Cost: 2.227724
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch   98/100 Batch 3/3 Cost: 2.331427
# 0
# [tensor([[73., 80., 75.],
#         [73., 66., 70.]]), tensor([[152.],
#         [142.]])]
# Epoch   99/100 Batch 1/3 Cost: 3.105932
# 1
# [tensor([[93., 88., 93.],
#         [89., 91., 90.]]), tensor([[185.],
#         [180.]])]
# Epoch   99/100 Batch 2/3 Cost: 0.864146
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch   99/100 Batch 3/3 Cost: 1.994182
# 0
# [tensor([[ 93.,  88.,  93.],
#         [ 96.,  98., 100.]]), tensor([[185.],
#         [196.]])]
# Epoch  100/100 Batch 1/3 Cost: 1.783012
# 1
# [tensor([[89., 91., 90.],
#         [73., 80., 75.]]), tensor([[180.],
#         [152.]])]
# Epoch  100/100 Batch 2/3 Cost: 0.036291
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch  100/100 Batch 3/3 Cost: 5.310952

# %%
# 임의의 입력 [73,80,75]를 선언
new_var=torch.FloatTensor([[73,80,75]])
# 입력한 값 [73,80,75]에 대해서 예측값 y를 리턴, pred_y에 저장
pred_y=model(new_var)
print('훈련 후 입력이 73,80,75일때의 예측값 :',pred_y)
# Out:
# 훈련 후 입력이 73,80,75일때의 예측값 : tensor([[152.5696]], grad_fn=<AddmmBackward0>)
