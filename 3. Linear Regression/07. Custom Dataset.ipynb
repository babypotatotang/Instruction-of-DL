# %% [markdown]
# # **<u>7. 커스텀 데이터셋(Custom DataSet)</u>**
# ## **1. 커스텀데이터셋**
# * `torch.utils.data.Dataset`을 상속받아 직접 커스텀 데이터셋을 만드는 경우 존재
# * `torch.utils.data.Dataset`은 파이토치에서 데이터셋을 제공하는 추상 클래스
# * Dataset을 상속받아 다음 메소드를 오버라이드하여 커스텀 데이터셋을 만들어봤음.

# %%
class CustomDataset(torch.utils.data.Dataset):
    def __init__(self):
        # 데이터셋의 전처리

    def __len__(self):
        # 데이터셋의 길이. 즉, 총 샘플의 수를 반환
    
    def __getitem__(self, idx):
        # 데이터셋에서 특정 1개의 샘플을 가져옴.

# %% [markdown]
# * 기본적인 뼈대는 다음과 같음.
#   * `init()`
#     - 데이터의 전처리 수행
#   * `len()`
#     - 데이터셋의 길이 리턴
#     - `len(dataset)`을 했을때, 데이터셋의 크기를 리턴
#   * `getitem()`
#     - 데이터셋에서 특정 1개의 샘플을 가져옴.
#     - `dataset[i]`를 했을때 i번째 샘플을 가져오도록 하는 **인덱싱**

# %% [markdown]
# ## **2. 커스텀 데이터셋으로 선형회귀 구현하기**

# %%
import torch 
import torch.nn.functional as F

# %%
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# %%
# Dataset 상송
class CustomDataset(Dataset):
    def __init__(self):
        self.x_data=[[73,80,75],
                     [93,88,93],
                     [89,91,90],
                     [96,98,100],
                     [73,66,70]]
        self.y_data=[[152],[185],[180],[196],[142]]

    # 총 데이터의 개수 리턴
    def __len__(self):
        return len(self.x_data)
    
    # 인덱스를 입력받아 그에 맵핑되는 입출력 데이터를 파이토치의 Tensor 형태로 리턴
    def __getitem__(self,idx):
        x = torch.FloatTensor(self.x_data[idx])
        y = torch.FloatTensor(self.y_data[idx])
        return x,y

# %%
dataset = CustomDataset()
dataloader = DataLoader(dataset,batch_size=2, shuffle=True)

# %%
model=torch.nn.Linear(3,1)
optimizer=torch.optim.SGD(model.parameters(),lr=1e-5)

# %%
nb_epochs=30
for epoch in range(nb_epochs+1):
    for batch_idx,samples in enumerate(dataloader):
        print(batch_idx)
        print(samples)

        x_train,y_train=samples

        prediction=model(x_train)
        cost=F.mse_loss(prediction,y_train)

        #cost로 prediction 개선 
        optimizer.zero_grad()
        cost.backward()
        optimizer.step()

        print('Epoch {:4d}/{} Batch {}/{} Cost:{:6f}'.format(epoch, nb_epochs,batch_idx,len(dataloader),cost.item()))
# Out:
# 0
# [tensor([[89., 91., 90.],
#         [93., 88., 93.]]), tensor([[180.],
#         [185.]])]
# Epoch    0/30 Batch 0/3 Cost:1.153904
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Epoch    0/30 Batch 1/3 Cost:0.514120
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch    0/30 Batch 2/3 Cost:15.306988
# 0
# [tensor([[73., 80., 75.],
#         [89., 91., 90.]]), tensor([[152.],
#         [180.]])]
# Epoch    1/30 Batch 0/3 Cost:3.464334
# 1
# [tensor([[ 73.,  66.,  70.],
#         [ 96.,  98., 100.]]), tensor([[142.],
#         [196.]])]
# Epoch    1/30 Batch 1/3 Cost:5.094254
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch    1/30 Batch 2/3 Cost:3.410620
# 0
# [tensor([[89., 91., 90.],
#         [93., 88., 93.]]), tensor([[180.],
#         [185.]])]
# Epoch    2/30 Batch 0/3 Cost:0.861025
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Epoch    2/30 Batch 1/3 Cost:0.239669
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch    2/30 Batch 2/3 Cost:16.289999
# 0
# [tensor([[ 73.,  80.,  75.],
#         [ 96.,  98., 100.]]), tensor([[152.],
#         [196.]])]
# Epoch    3/30 Batch 0/3 Cost:5.178563
# 1
# [tensor([[89., 91., 90.],
#         [73., 66., 70.]]), tensor([[180.],
#         [142.]])]
# Epoch    3/30 Batch 1/3 Cost:1.832143
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch    3/30 Batch 2/3 Cost:3.880364
# 0
# [tensor([[ 73.,  66.,  70.],
#         [ 96.,  98., 100.]]), tensor([[142.],
#         [196.]])]
# Epoch    4/30 Batch 0/3 Cost:0.290284
# 1
# [tensor([[89., 91., 90.],
#         [73., 80., 75.]]), tensor([[180.],
#         [152.]])]
# Epoch    4/30 Batch 1/3 Cost:8.589686
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch    4/30 Batch 2/3 Cost:3.478530
# 0
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Epoch    5/30 Batch 0/3 Cost:0.247240
# 1
# [tensor([[73., 80., 75.],
#         [93., 88., 93.]]), tensor([[152.],
#         [185.]])]
# Epoch    5/30 Batch 1/3 Cost:8.360373
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch    5/30 Batch 2/3 Cost:0.217458
# 0
# [tensor([[ 73.,  66.,  70.],
#         [ 96.,  98., 100.]]), tensor([[142.],
#         [196.]])]
# Epoch    6/30 Batch 0/3 Cost:1.193349
# 1
# [tensor([[89., 91., 90.],
#         [73., 80., 75.]]), tensor([[180.],
#         [152.]])]
# Epoch    6/30 Batch 1/3 Cost:7.094803
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch    6/30 Batch 2/3 Cost:4.295297
# 0
# [tensor([[ 73.,  80.,  75.],
#         [ 96.,  98., 100.]]), tensor([[152.],
#         [196.]])]
# Epoch    7/30 Batch 0/3 Cost:7.170847
# 1
# [tensor([[89., 91., 90.],
#         [93., 88., 93.]]), tensor([[180.],
#         [185.]])]
# Epoch    7/30 Batch 1/3 Cost:1.483761
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch    7/30 Batch 2/3 Cost:0.899134
# 0
# [tensor([[ 93.,  88.,  93.],
#         [ 96.,  98., 100.]]), tensor([[185.],
#         [196.]])]
# Epoch    8/30 Batch 0/3 Cost:0.504280
# 1
# [tensor([[73., 80., 75.],
#         [73., 66., 70.]]), tensor([[152.],
#         [142.]])]
# Epoch    8/30 Batch 1/3 Cost:8.472676
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch    8/30 Batch 2/3 Cost:0.194059
# 0
# [tensor([[ 73.,  66.,  70.],
#         [ 96.,  98., 100.]]), tensor([[142.],
#         [196.]])]
# Epoch    9/30 Batch 0/3 Cost:1.211797
# 1
# [tensor([[89., 91., 90.],
#         [93., 88., 93.]]), tensor([[180.],
#         [185.]])]
# Epoch    9/30 Batch 1/3 Cost:0.893158
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch    9/30 Batch 2/3 Cost:14.229044
# 0
# [tensor([[ 73.,  80.,  75.],
#         [ 96.,  98., 100.]]), tensor([[152.],
#         [196.]])]
# Epoch   10/30 Batch 0/3 Cost:5.142538
# 1
# [tensor([[73., 66., 70.],
#         [93., 88., 93.]]), tensor([[142.],
#         [185.]])]
# Epoch   10/30 Batch 1/3 Cost:5.035937
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch   10/30 Batch 2/3 Cost:0.086521
# 0
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Epoch   11/30 Batch 0/3 Cost:1.362110
# 1
# [tensor([[73., 80., 75.],
#         [89., 91., 90.]]), tensor([[152.],
#         [180.]])]
# Epoch   11/30 Batch 1/3 Cost:6.868331
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   11/30 Batch 2/3 Cost:4.377274
# 0
# [tensor([[73., 80., 75.],
#         [89., 91., 90.]]), tensor([[152.],
#         [180.]])]
# Epoch   12/30 Batch 0/3 Cost:7.324998
# 1
# [tensor([[93., 88., 93.],
#         [73., 66., 70.]]), tensor([[185.],
#         [142.]])]
# Epoch   12/30 Batch 1/3 Cost:3.129033
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch   12/30 Batch 2/3 Cost:0.359038
# 0
# [tensor([[ 89.,  91.,  90.],
#         [ 96.,  98., 100.]]), tensor([[180.],
#         [196.]])]
# Epoch   13/30 Batch 0/3 Cost:0.459532
# 1
# [tensor([[73., 80., 75.],
#         [73., 66., 70.]]), tensor([[152.],
#         [142.]])]
# Epoch   13/30 Batch 1/3 Cost:7.205400
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   13/30 Batch 2/3 Cost:2.887915
# 0
# [tensor([[73., 66., 70.],
#         [89., 91., 90.]]), tensor([[142.],
#         [180.]])]
# Epoch   14/30 Batch 0/3 Cost:0.652943
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 93.,  88.,  93.]]), tensor([[196.],
#         [185.]])]
# Epoch   14/30 Batch 1/3 Cost:0.533952
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch   14/30 Batch 2/3 Cost:16.564463
# 0
# [tensor([[73., 80., 75.],
#         [89., 91., 90.]]), tensor([[152.],
#         [180.]])]
# Epoch   15/30 Batch 0/3 Cost:3.649884
# 1
# [tensor([[ 73.,  66.,  70.],
#         [ 96.,  98., 100.]]), tensor([[142.],
#         [196.]])]
# Epoch   15/30 Batch 1/3 Cost:4.644259
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   15/30 Batch 2/3 Cost:3.145568
# 0
# [tensor([[73., 66., 70.],
#         [89., 91., 90.]]), tensor([[142.],
#         [180.]])]
# Epoch   16/30 Batch 0/3 Cost:0.629515
# 1
# [tensor([[93., 88., 93.],
#         [73., 80., 75.]]), tensor([[185.],
#         [152.]])]
# Epoch   16/30 Batch 1/3 Cost:7.596093
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch   16/30 Batch 2/3 Cost:0.867329
# 0
# [tensor([[ 96.,  98., 100.],
#         [ 93.,  88.,  93.]]), tensor([[196.],
#         [185.]])]
# Epoch   17/30 Batch 0/3 Cost:0.612125
# 1
# [tensor([[73., 80., 75.],
#         [89., 91., 90.]]), tensor([[152.],
#         [180.]])]
# Epoch   17/30 Batch 1/3 Cost:8.829854
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch   17/30 Batch 2/3 Cost:1.696481
# 0
# [tensor([[93., 88., 93.],
#         [73., 66., 70.]]), tensor([[185.],
#         [142.]])]
# Epoch   18/30 Batch 0/3 Cost:1.265649
# 1
# [tensor([[ 89.,  91.,  90.],
#         [ 96.,  98., 100.]]), tensor([[180.],
#         [196.]])]
# Epoch   18/30 Batch 1/3 Cost:0.536600
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch   18/30 Batch 2/3 Cost:14.084710
# 0
# [tensor([[89., 91., 90.],
#         [73., 80., 75.]]), tensor([[180.],
#         [152.]])]
# Epoch   19/30 Batch 0/3 Cost:3.265996
# 1
# [tensor([[ 93.,  88.,  93.],
#         [ 96.,  98., 100.]]), tensor([[185.],
#         [196.]])]
# Epoch   19/30 Batch 1/3 Cost:7.104557
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch   19/30 Batch 2/3 Cost:1.209342
# 0
# [tensor([[93., 88., 93.],
#         [73., 80., 75.]]), tensor([[185.],
#         [152.]])]
# Epoch   20/30 Batch 0/3 Cost:7.329777
# 1
# [tensor([[73., 66., 70.],
#         [89., 91., 90.]]), tensor([[142.],
#         [180.]])]
# Epoch   20/30 Batch 1/3 Cost:0.686372
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch   20/30 Batch 2/3 Cost:0.688422
# 0
# [tensor([[93., 88., 93.],
#         [89., 91., 90.]]), tensor([[185.],
#         [180.]])]
# Epoch   21/30 Batch 0/3 Cost:0.833321
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  80.,  75.]]), tensor([[196.],
#         [152.]])]
# Epoch   21/30 Batch 1/3 Cost:7.262267
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch   21/30 Batch 2/3 Cost:1.421777
# 0
# [tensor([[73., 66., 70.],
#         [89., 91., 90.]]), tensor([[142.],
#         [180.]])]
# Epoch   22/30 Batch 0/3 Cost:0.550711
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  80.,  75.]]), tensor([[196.],
#         [152.]])]
# Epoch   22/30 Batch 1/3 Cost:6.615088
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   22/30 Batch 2/3 Cost:3.181446
# 0
# [tensor([[93., 88., 93.],
#         [89., 91., 90.]]), tensor([[185.],
#         [180.]])]
# Epoch   23/30 Batch 0/3 Cost:0.822840
# 1
# [tensor([[ 73.,  80.,  75.],
#         [ 96.,  98., 100.]]), tensor([[152.],
#         [196.]])]
# Epoch   23/30 Batch 1/3 Cost:7.383515
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch   23/30 Batch 2/3 Cost:1.366183
# 0
# [tensor([[89., 91., 90.],
#         [93., 88., 93.]]), tensor([[180.],
#         [185.]])]
# Epoch   24/30 Batch 0/3 Cost:0.897077
# 1
# [tensor([[ 73.,  66.,  70.],
#         [ 96.,  98., 100.]]), tensor([[142.],
#         [196.]])]
# Epoch   24/30 Batch 1/3 Cost:0.347073
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch   24/30 Batch 2/3 Cost:15.348925
# 0
# [tensor([[73., 80., 75.],
#         [93., 88., 93.]]), tensor([[152.],
#         [185.]])]
# Epoch   25/30 Batch 0/3 Cost:6.201710
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 89.,  91.,  90.]]), tensor([[196.],
#         [180.]])]
# Epoch   25/30 Batch 1/3 Cost:1.788627
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch   25/30 Batch 2/3 Cost:1.559793
# 0
# [tensor([[73., 80., 75.],
#         [73., 66., 70.]]), tensor([[152.],
#         [142.]])]
# Epoch   26/30 Batch 0/3 Cost:6.609562
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 89.,  91.,  90.]]), tensor([[196.],
#         [180.]])]
# Epoch   26/30 Batch 1/3 Cost:0.785798
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   26/30 Batch 2/3 Cost:2.196218
# 0
# [tensor([[73., 66., 70.],
#         [73., 80., 75.]]), tensor([[142.],
#         [152.]])]
# Epoch   27/30 Batch 0/3 Cost:7.927245
# 1
# [tensor([[ 89.,  91.,  90.],
#         [ 96.,  98., 100.]]), tensor([[180.],
#         [196.]])]
# Epoch   27/30 Batch 1/3 Cost:0.446207
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   27/30 Batch 2/3 Cost:1.733930
# 0
# [tensor([[89., 91., 90.],
#         [73., 80., 75.]]), tensor([[180.],
#         [152.]])]
# Epoch   28/30 Batch 0/3 Cost:8.722242
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Epoch   28/30 Batch 1/3 Cost:1.553002
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   28/30 Batch 2/3 Cost:1.452434
# 0
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  80.,  75.]]), tensor([[196.],
#         [152.]])]
# Epoch   29/30 Batch 0/3 Cost:8.244118
# 1
# [tensor([[73., 66., 70.],
#         [93., 88., 93.]]), tensor([[142.],
#         [185.]])]
# Epoch   29/30 Batch 1/3 Cost:1.604753
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch   29/30 Batch 2/3 Cost:0.819962
# 0
# [tensor([[ 96.,  98., 100.],
#         [ 93.,  88.,  93.]]), tensor([[196.],
#         [185.]])]
# Epoch   30/30 Batch 0/3 Cost:1.179707
# 1
# [tensor([[89., 91., 90.],
#         [73., 80., 75.]]), tensor([[180.],
#         [152.]])]
# Epoch   30/30 Batch 1/3 Cost:8.051867
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch   30/30 Batch 2/3 Cost:1.805254
